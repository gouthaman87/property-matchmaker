# %% [markdown]
# # Property Matchmaker (Gemini - Free)

# %%
import os
from dotenv import load_dotenv

load_dotenv()

# If .env doesn't exist yet, set your key directly:
# os.environ["GOOGLE_API_KEY"] = "your-google-api-key-here"

# %%
from modelling.function_gemini import PropertyMatchmaker

# %% [markdown]
# ## 1. Initialize the Property Matchmaker

# %%
# Initialize with your Excel database
matchmaker = PropertyMatchmaker()
print(f"Data shape: {matchmaker.df.shape[0]} rows × {matchmaker.df.shape[1]} columns")

# %% [markdown]
# ## 4. Run a Search

# %%
query_1 = """Land Size: 4/10 acre 
Location: Colombo/Colombo suburbs

This is for the housing project."""

query_2 = """Apartment Rental Requirement

A client is looking for an apartment for rent with the following specifications:

Bedrooms: 3 bedrooms

Status: Unfinished

Location: Colombo 4, Colombo 6, or Dickmans Road

Not interested in sea-side locations

Not interested in properties near Hampden Lane
Close to Galle Road if in Colombo 6

Preferred Property:  Flemington Apartments, Vajira Road

Budget: LKR 200,000 – 250,000 per month

Direct
"""

query_3 = """“Apartment wanted in address 606”"""

query_4 = """3 bedroom apartments for sale in Colombo 3"""

query_5 = """Looking for a one bedroom apartment to purchase at Trizen 
Budget 50 million below
"""

result = matchmaker.search_properties(query_3)
print(result)
